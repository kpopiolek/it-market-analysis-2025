# %%
import pandas as pd
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
data = pd.read_csv(r"C:\Users\Krzysiek\Desktop\studia\kurs\projekty\rynek_it\survey_results_public.csv", low_memory=False)

# %%
df_extracted = data[[ 'Age', 'EdLevel', 'WorkExp', 'ConvertedCompYearly', 'Country', 'YearsCode', 'OrgSize', 'Industry', 'AISelect']]
df_extracted
df_extracted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49191 entries, 0 to 49190
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  49191 non-null  object
#  1   EdLevel              48149 non-null  object
#  2   WorkExp              42893 non-null  float64
#  3   ConvertedCompYearly  23947 non-null  float64
#  4   Country              35437 non-null  object
#  5   YearsCode            43042 non-null  float64
#  6   OrgSize              34178 non-null  object
#  7   Industry             33642 non-null  object
#  8   AISelect             33720 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 3.4+ MB

# %%
df_cut = df_extracted.dropna(subset='ConvertedCompYearly')
df_cut.reset_index(drop=True, inplace = True)
df_cut['ConvertedCompYearly'] = df_cut['ConvertedCompYearly'] / 12
df_cut
# Out:
# C:\Users\Krzysiek\AppData\Local\Temp\ipykernel_17680\1465661977.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cut['ConvertedCompYearly'] = df_cut['ConvertedCompYearly'] / 12
#                    Age                                            EdLevel  \
# 0      25-34 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1      25-34 years old                Associate degree (A.A., A.S., etc.)
# 2      35-44 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3      35-44 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4      35-44 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                ...                                                ...
# 23942  45-54 years old     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 23943  18-24 years old  Some college/university study without earning ...
# 23944  45-54 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 23945  25-34 years old                Associate degree (A.A., A.S., etc.)
# 23946  25-34 years old  Some college/university study without earning ...
#
#        WorkExp  ConvertedCompYearly       Country  YearsCode  \
# 0          8.0          5104.666667       Ukraine       14.0
# 1          2.0          8701.083333   Netherlands       10.0
# 2         10.0          4421.750000       Ukraine       12.0
# 3          4.0          3016.416667       Ukraine        5.0
# 4         21.0          5000.000000       Ukraine       22.0
# ...        ...                  ...           ...        ...
# 23942      8.0           227.416667        Poland        6.0
# 23943      1.0            59.916667         Egypt        1.0
# 23944     29.0          5750.666667  South Africa       29.0
# 23945     10.0          4833.916667        France       14.0
# 23946     10.0          3867.166667         Italy       15.0
#
#                         OrgSize                      Industry  \
# 0            20 to 99 employees                       Fintech
# 1          500 to 999 employees  Retail and Consumer Services
# 2                           NaN          Software Development
# 3      10,000 or more employees  Retail and Consumer Services
# 4                           NaN          Software Development
# ...                         ...                           ...
# 23942  1,000 to 4,999 employees          Software Development
# 23943        20 to 99 employees          Software Development
# 23944      100 to 499 employees          Software Development
# 23945        20 to 99 employees                 Manufacturing
# 23946    Less than 20 employees          Software Development
#
#                                           AISelect
# 0      Yes, I use AI tools monthly or infrequently
# 1                       Yes, I use AI tools weekly
# 2                        Yes, I use AI tools daily
# 3                       Yes, I use AI tools weekly
# 4                       Yes, I use AI tools weekly
# ...                                            ...
# 23942                    Yes, I use AI tools daily
# 23943                                          NaN
# 23944                    Yes, I use AI tools daily
# 23945                    Yes, I use AI tools daily
# 23946                                          NaN
#
# [23947 rows x 9 columns]

# %%
num = df_cut['Country'].value_counts()
countries = num[num>=100].index
df_cut = df_cut[df_cut['Country'].isin(countries)]
df_cut
# Out:
#                    Age                                            EdLevel  \
# 0      25-34 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1      25-34 years old                Associate degree (A.A., A.S., etc.)
# 2      35-44 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3      35-44 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4      35-44 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                ...                                                ...
# 23941  18-24 years old  Secondary school (e.g. American high school, G...
# 23942  45-54 years old     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 23944  45-54 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 23945  25-34 years old                Associate degree (A.A., A.S., etc.)
# 23946  25-34 years old  Some college/university study without earning ...
#
#        WorkExp  ConvertedCompYearly       Country  YearsCode  \
# 0          8.0          5104.666667       Ukraine       14.0
# 1          2.0          8701.083333   Netherlands       10.0
# 2         10.0          4421.750000       Ukraine       12.0
# 3          4.0          3016.416667       Ukraine        5.0
# 4         21.0          5000.000000       Ukraine       22.0
# ...        ...                  ...           ...        ...
# 23941      1.0           387.500000         India        2.0
# 23942      8.0           227.416667        Poland        6.0
# 23944     29.0          5750.666667  South Africa       29.0
# 23945     10.0          4833.916667        France       14.0
# 23946     10.0          3867.166667         Italy       15.0
#
#                         OrgSize                      Industry  \
# 0            20 to 99 employees                       Fintech
# 1          500 to 999 employees  Retail and Consumer Services
# 2                           NaN          Software Development
# 3      10,000 or more employees  Retail and Consumer Services
# 4                           NaN          Software Development
# ...                         ...                           ...
# 23941                       NaN                           NaN
# 23942  1,000 to 4,999 employees          Software Development
# 23944      100 to 499 employees          Software Development
# 23945        20 to 99 employees                 Manufacturing
# 23946    Less than 20 employees          Software Development
#
#                                           AISelect
# 0      Yes, I use AI tools monthly or infrequently
# 1                       Yes, I use AI tools weekly
# 2                        Yes, I use AI tools daily
# 3                       Yes, I use AI tools weekly
# 4                       Yes, I use AI tools weekly
# ...                                            ...
# 23941  Yes, I use AI tools monthly or infrequently
# 23942                    Yes, I use AI tools daily
# 23944                    Yes, I use AI tools daily
# 23945                    Yes, I use AI tools daily
# 23946                                          NaN
#
# [21767 rows x 9 columns]

# %%
ed_map = {
    "Bachelor’s degree (B.A., B.S., B.Eng., etc.)": "Bachelor",
    "Master’s degree (M.A., M.S., M.Eng., MBA, etc.)": "Master",
    "Professional degree (JD, MD, Ph.D, Ed.D, etc.)": "Postgrad/PhD",
    "Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)": "High School",
    "Some college/university study without earning a degree": "Undergrad/No degree",
    "Associate degree (A.A., A.S., etc.)": "Associate",
    "Other (please specify):" : "Other",   
    "Primary/elementary school" : "Primary School"
}

df_cut = df_cut.copy()
df_cut['EdLevel'] = df_cut['EdLevel'].replace(ed_map)

# Sprawdźmy, czy zadziałało
df_cut['EdLevel'].value_counts()
# Out:
# EdLevel
# Bachelor               9297
# Master                 6445
# Undergrad/No degree    2580
# Postgrad/PhD           1281
# High School            1110
# Associate               723
# Other                   202
# Primary School          114
# Name: count, dtype: int64

# %%
pd.options.display.float_format = '{:.2f}'.format
df_cut.describe()
# Out:
#        WorkExp  ConvertedCompYearly  YearsCode
# count 21365.00             21767.00   21675.00
# mean     14.01              8825.27      18.14
# std      10.19             39143.38      11.09
# min       1.00                 0.08       1.00
# 25%       6.00              3670.25      10.00
# 50%      12.00              6666.67      15.00
# 75%      20.00             10500.00      25.00
# max     100.00           4166666.67     100.00

# %%
df_cut
# Out:
#                    Age              EdLevel  WorkExp  ConvertedCompYearly  \
# 0      25-34 years old               Master     8.00              5104.67
# 1      25-34 years old            Associate     2.00              8701.08
# 2      35-44 years old             Bachelor    10.00              4421.75
# 3      35-44 years old             Bachelor     4.00              3016.42
# 4      35-44 years old               Master    21.00              5000.00
# ...                ...                  ...      ...                  ...
# 23941  18-24 years old          High School     1.00               387.50
# 23942  45-54 years old         Postgrad/PhD     8.00               227.42
# 23944  45-54 years old             Bachelor    29.00              5750.67
# 23945  25-34 years old            Associate    10.00              4833.92
# 23946  25-34 years old  Undergrad/No degree    10.00              3867.17
#
#             Country  YearsCode                   OrgSize  \
# 0           Ukraine      14.00        20 to 99 employees
# 1       Netherlands      10.00      500 to 999 employees
# 2           Ukraine      12.00                       NaN
# 3           Ukraine       5.00  10,000 or more employees
# 4           Ukraine      22.00                       NaN
# ...             ...        ...                       ...
# 23941         India       2.00                       NaN
# 23942        Poland       6.00  1,000 to 4,999 employees
# 23944  South Africa      29.00      100 to 499 employees
# 23945        France      14.00        20 to 99 employees
# 23946         Italy      15.00    Less than 20 employees
#
#                            Industry  \
# 0                           Fintech
# 1      Retail and Consumer Services
# 2              Software Development
# 3      Retail and Consumer Services
# 4              Software Development
# ...                             ...
# 23941                           NaN
# 23942          Software Development
# 23944          Software Development
# 23945                 Manufacturing
# 23946          Software Development
#
#                                           AISelect
# 0      Yes, I use AI tools monthly or infrequently
# 1                       Yes, I use AI tools weekly
# 2                        Yes, I use AI tools daily
# 3                       Yes, I use AI tools weekly
# 4                       Yes, I use AI tools weekly
# ...                                            ...
# 23941  Yes, I use AI tools monthly or infrequently
# 23942                    Yes, I use AI tools daily
# 23944                    Yes, I use AI tools daily
# 23945                    Yes, I use AI tools daily
# 23946                                          NaN
#
# [21767 rows x 9 columns]

# %%
df_cut['Age'].value_counts()
# Out:
# Age
# 25-34 years old      7616
# 35-44 years old      6981
# 45-54 years old      3263
# 18-24 years old      2245
# 55-64 years old      1326
# 65 years or older     318
# Prefer not to say      18
# Name: count, dtype: int64

# %%
age_map = {
    "18-24 years old" : 24,
    "25-34 years old" : 34,
    "35-44 years old" : 44,
    "45-54 years old" : 54,
    "55-64 years old" : 64,
    "Prefer not to say" : 0,
    "65 years or older" : 74
}
df_cut['Age'] = df_cut['Age'].replace(age_map)
# Out:
# C:\Users\Krzysiek\AppData\Local\Temp\ipykernel_17680\927208133.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_cut['Age'] = df_cut['Age'].replace(age_map)

# %%
wrong_values = df_cut['Age'] - df_cut['WorkExp'] < 16
print("wrong values count: ", wrong_values.sum())
df_cut = df_cut[~wrong_values]
# Out:
# wrong values count:  118

# %%
df_cut
# Out:
#        Age              EdLevel  WorkExp  ConvertedCompYearly       Country  \
# 0       34               Master     8.00              5104.67       Ukraine
# 1       34            Associate     2.00              8701.08   Netherlands
# 2       44             Bachelor    10.00              4421.75       Ukraine
# 3       44             Bachelor     4.00              3016.42       Ukraine
# 4       44               Master    21.00              5000.00       Ukraine
# ...    ...                  ...      ...                  ...           ...
# 23941   24          High School     1.00               387.50         India
# 23942   54         Postgrad/PhD     8.00               227.42        Poland
# 23944   54             Bachelor    29.00              5750.67  South Africa
# 23945   34            Associate    10.00              4833.92        France
# 23946   34  Undergrad/No degree    10.00              3867.17         Italy
#
#        YearsCode                   OrgSize                      Industry  \
# 0          14.00        20 to 99 employees                       Fintech
# 1          10.00      500 to 999 employees  Retail and Consumer Services
# 2          12.00                       NaN          Software Development
# 3           5.00  10,000 or more employees  Retail and Consumer Services
# 4          22.00                       NaN          Software Development
# ...          ...                       ...                           ...
# 23941       2.00                       NaN                           NaN
# 23942       6.00  1,000 to 4,999 employees          Software Development
# 23944      29.00      100 to 499 employees          Software Development
# 23945      14.00        20 to 99 employees                 Manufacturing
# 23946      15.00    Less than 20 employees          Software Development
#
#                                           AISelect
# 0      Yes, I use AI tools monthly or infrequently
# 1                       Yes, I use AI tools weekly
# 2                        Yes, I use AI tools daily
# 3                       Yes, I use AI tools weekly
# 4                       Yes, I use AI tools weekly
# ...                                            ...
# 23941  Yes, I use AI tools monthly or infrequently
# 23942                    Yes, I use AI tools daily
# 23944                    Yes, I use AI tools daily
# 23945                    Yes, I use AI tools daily
# 23946                                          NaN
#
# [21649 rows x 9 columns]

# %%
df_cut.isnull().sum()
# Out:
# Age                       0
# EdLevel                  15
# WorkExp                 402
# ConvertedCompYearly       0
# Country                   0
# YearsCode                91
# OrgSize                2412
# Industry                770
# AISelect                640
# dtype: int64

# %%
df_cut = df_cut.dropna()
df_cut.reset_index(drop=True, inplace = True)
df_cut
# Out:
#        Age       EdLevel  WorkExp  ConvertedCompYearly  \
# 0       34        Master     8.00              5104.67
# 1       34     Associate     2.00              8701.08
# 2       44      Bachelor     4.00              3016.42
# 3       44  Postgrad/PhD    22.00              6000.00
# 4       34      Bachelor     9.00              5833.33
# ...    ...           ...      ...                  ...
# 18354   34        Master     4.00              6863.83
# 18355   44      Bachelor    22.00             15666.67
# 18356   54  Postgrad/PhD     8.00               227.42
# 18357   54      Bachelor    29.00              5750.67
# 18358   34     Associate    10.00              4833.92
#
#                                                  Country  YearsCode  \
# 0                                                Ukraine      14.00
# 1                                            Netherlands      10.00
# 2                                                Ukraine       5.00
# 3                                                Ukraine      30.00
# 4                                                Ukraine      15.00
# ...                                                  ...        ...
# 18354  United Kingdom of Great Britain and Northern I...      10.00
# 18355                           United States of America       5.00
# 18356                                             Poland       6.00
# 18357                                       South Africa      29.00
# 18358                                             France      14.00
#
#                         OrgSize                         Industry  \
# 0            20 to 99 employees                          Fintech
# 1          500 to 999 employees     Retail and Consumer Services
# 2      10,000 or more employees     Retail and Consumer Services
# 3        Less than 20 employees             Software Development
# 4      5,000 to 9,999 employees       Banking/Financial Services
# ...                         ...                              ...
# 18354  1,000 to 4,999 employees  Transportation, or Supply Chain
# 18355  10,000 or more employees     Retail and Consumer Services
# 18356  1,000 to 4,999 employees             Software Development
# 18357      100 to 499 employees             Software Development
# 18358        20 to 99 employees                    Manufacturing
#
#                                           AISelect
# 0      Yes, I use AI tools monthly or infrequently
# 1                       Yes, I use AI tools weekly
# 2                       Yes, I use AI tools weekly
# 3                        Yes, I use AI tools daily
# 4      Yes, I use AI tools monthly or infrequently
# ...                                            ...
# 18354                   Yes, I use AI tools weekly
# 18355                    Yes, I use AI tools daily
# 18356                    Yes, I use AI tools daily
# 18357                    Yes, I use AI tools daily
# 18358                    Yes, I use AI tools daily
#
# [18359 rows x 9 columns]

# %%
df_cut = df_cut.copy()

q1 = df_cut.groupby('Country')['ConvertedCompYearly'].transform(lambda x: x.quantile(0.25))
q3 = df_cut.groupby('Country')['ConvertedCompYearly'].transform(lambda x: x.quantile(0.75))
iqr = q3 - q1
limU = q3 + 1.5 * iqr
limD = q1 - 1.5 * iqr
df_cut = df_cut[ ( df_cut['ConvertedCompYearly'] >= limD ) & (df_cut['ConvertedCompYearly'] <= limU) ]

# %%
df_cut
# Out:
#        Age       EdLevel  WorkExp  ConvertedCompYearly  \
# 0       34        Master     8.00              5104.67
# 1       34     Associate     2.00              8701.08
# 2       44      Bachelor     4.00              3016.42
# 3       44  Postgrad/PhD    22.00              6000.00
# 4       34      Bachelor     9.00              5833.33
# ...    ...           ...      ...                  ...
# 18354   34        Master     4.00              6863.83
# 18355   44      Bachelor    22.00             15666.67
# 18356   54  Postgrad/PhD     8.00               227.42
# 18357   54      Bachelor    29.00              5750.67
# 18358   34     Associate    10.00              4833.92
#
#                                                  Country  YearsCode  \
# 0                                                Ukraine      14.00
# 1                                            Netherlands      10.00
# 2                                                Ukraine       5.00
# 3                                                Ukraine      30.00
# 4                                                Ukraine      15.00
# ...                                                  ...        ...
# 18354  United Kingdom of Great Britain and Northern I...      10.00
# 18355                           United States of America       5.00
# 18356                                             Poland       6.00
# 18357                                       South Africa      29.00
# 18358                                             France      14.00
#
#                         OrgSize                         Industry  \
# 0            20 to 99 employees                          Fintech
# 1          500 to 999 employees     Retail and Consumer Services
# 2      10,000 or more employees     Retail and Consumer Services
# 3        Less than 20 employees             Software Development
# 4      5,000 to 9,999 employees       Banking/Financial Services
# ...                         ...                              ...
# 18354  1,000 to 4,999 employees  Transportation, or Supply Chain
# 18355  10,000 or more employees     Retail and Consumer Services
# 18356  1,000 to 4,999 employees             Software Development
# 18357      100 to 499 employees             Software Development
# 18358        20 to 99 employees                    Manufacturing
#
#                                           AISelect
# 0      Yes, I use AI tools monthly or infrequently
# 1                       Yes, I use AI tools weekly
# 2                       Yes, I use AI tools weekly
# 3                        Yes, I use AI tools daily
# 4      Yes, I use AI tools monthly or infrequently
# ...                                            ...
# 18354                   Yes, I use AI tools weekly
# 18355                    Yes, I use AI tools daily
# 18356                    Yes, I use AI tools daily
# 18357                    Yes, I use AI tools daily
# 18358                    Yes, I use AI tools daily
#
# [17413 rows x 9 columns]

# %%
df_cut['Country'] = df_cut['Country'].replace({
    "United Kingdom of Great Britain and Northern Ireland" : "UK and NI",
    "United States of America" : "USA",
    "Russian Federation" : "Russia"
})
df_cut['Country'].nunique()
# Out:
# 42

# %%
sorted_median = df_cut.groupby('Country', observed = True)['ConvertedCompYearly'].median().sort_values()
df_cut['Country'] = pd.Categorical(df_cut['Country'], categories = sorted_median.index, ordered = True)

# %%
df_cut.boxplot(
    column = 'ConvertedCompYearly', 
    by = 'Country', 
    figsize = (10, 20), 
    vert = False, showmeans = True, 
    color = 'black', 
    boxprops={'linewidth': 2.5}, 
    medianprops={'linewidth': 2.5}, 
    whiskerprops={'linewidth': 2.5})

plt.suptitle('')
plt.title("Monthly salary of IT Professionals in different countries (USD)", fontsize = 18, pad = 20)
plt.xlabel("Monthly salary in USD", fontsize = 14, labelpad = 15)
plt.ylabel("Country", fontsize = 14, labelpad = 15)
plt.xticks( range(0, 30000, 5000) )
plt.xlim(left = 0)
plt.tick_params('x', top = True, labeltop = True )
plt.axvline(x = 10000 , linestyle = '-', linewidth = 2, alpha = 0.5, color = 'gray')
plt.axvline(x = 20000 , linestyle = '-', linewidth = 2, alpha = 0.5, color = 'gray')

# %%
df_cut['OrgSize'].value_counts()
# Out:
# OrgSize
# 20 to 99 employees                                    3543
# 100 to 499 employees                                  3405
# 10,000 or more employees                              2612
# Less than 20 employees                                2608
# 1,000 to 4,999 employees                              2313
# 500 to 999 employees                                  1332
# 5,000 to 9,999 employees                               879
# Just me - I am a freelancer, sole proprietor, etc.     478
# I don’t know                                           243
# Name: count, dtype: int64

# %%
df_cut['EdLevel'].value_counts()
# Out:
# EdLevel
# Bachelor               7597
# Master                 5178
# Undergrad/No degree    2002
# Postgrad/PhD           1036
# High School             786
# Associate               596
# Other                   153
# Primary School           65
# Name: count, dtype: int64

# %%
ed_map = {
    'Primary School': 1,
    'High School': 2,
    'Other': 3,
    'Undergrad/No degree': 4,
    'Associate': 5,
    'Bachelor': 6,
    'Master': 7,
    'Postgrad/PhD': 8
}

org_map = {
    "I don't know" : 0,
    "Just me - I am a freelancer, sole proprietor, etc." : 1,
    "Less than 20 employees" : 2,
    "20 to 99 employees" : 3,
    "100 to 499 employees" : 4,
    "500 to 999 employees" : 5,
    "1,000 to 4,999 employees" : 6,
    "5,000 to 9,999 employees" : 7,
    "10,000 or more employees" : 8
}

# %%
df_stats = df_cut.copy()

df_stats
# Out:
#        Age       EdLevel  WorkExp  ConvertedCompYearly       Country  \
# 0       34        Master     8.00              5104.67       Ukraine
# 1       34     Associate     2.00              8701.08   Netherlands
# 2       44      Bachelor     4.00              3016.42       Ukraine
# 3       44  Postgrad/PhD    22.00              6000.00       Ukraine
# 4       34      Bachelor     9.00              5833.33       Ukraine
# ...    ...           ...      ...                  ...           ...
# 18354   34        Master     4.00              6863.83     UK and NI
# 18355   44      Bachelor    22.00             15666.67           USA
# 18356   54  Postgrad/PhD     8.00               227.42        Poland
# 18357   54      Bachelor    29.00              5750.67  South Africa
# 18358   34     Associate    10.00              4833.92        France
#
#        YearsCode                   OrgSize                         Industry  \
# 0          14.00        20 to 99 employees                          Fintech
# 1          10.00      500 to 999 employees     Retail and Consumer Services
# 2           5.00  10,000 or more employees     Retail and Consumer Services
# 3          30.00    Less than 20 employees             Software Development
# 4          15.00  5,000 to 9,999 employees       Banking/Financial Services
# ...          ...                       ...                              ...
# 18354      10.00  1,000 to 4,999 employees  Transportation, or Supply Chain
# 18355       5.00  10,000 or more employees     Retail and Consumer Services
# 18356       6.00  1,000 to 4,999 employees             Software Development
# 18357      29.00      100 to 499 employees             Software Development
# 18358      14.00        20 to 99 employees                    Manufacturing
#
#                                           AISelect
# 0      Yes, I use AI tools monthly or infrequently
# 1                       Yes, I use AI tools weekly
# 2                       Yes, I use AI tools weekly
# 3                        Yes, I use AI tools daily
# 4      Yes, I use AI tools monthly or infrequently
# ...                                            ...
# 18354                   Yes, I use AI tools weekly
# 18355                    Yes, I use AI tools daily
# 18356                    Yes, I use AI tools daily
# 18357                    Yes, I use AI tools daily
# 18358                    Yes, I use AI tools daily
#
# [17413 rows x 9 columns]

# %%
df_stats['OrgSize'] = df_stats['OrgSize'].replace(org_map)
df_stats['EdLevel'] = df_stats['EdLevel'].replace(ed_map)
df_stats
# Out:
#        Age  EdLevel  WorkExp  ConvertedCompYearly       Country  YearsCode  \
# 0       34        7     8.00              5104.67       Ukraine      14.00
# 1       34        5     2.00              8701.08   Netherlands      10.00
# 2       44        6     4.00              3016.42       Ukraine       5.00
# 3       44        8    22.00              6000.00       Ukraine      30.00
# 4       34        6     9.00              5833.33       Ukraine      15.00
# ...    ...      ...      ...                  ...           ...        ...
# 18354   34        7     4.00              6863.83     UK and NI      10.00
# 18355   44        6    22.00             15666.67           USA       5.00
# 18356   54        8     8.00               227.42        Poland       6.00
# 18357   54        6    29.00              5750.67  South Africa      29.00
# 18358   34        5    10.00              4833.92        France      14.00
#
#       OrgSize                         Industry  \
# 0           3                          Fintech
# 1           5     Retail and Consumer Services
# 2           8     Retail and Consumer Services
# 3           2             Software Development
# 4           7       Banking/Financial Services
# ...       ...                              ...
# 18354       6  Transportation, or Supply Chain
# 18355       8     Retail and Consumer Services
# 18356       6             Software Development
# 18357       4             Software Development
# 18358       3                    Manufacturing
#
#                                           AISelect
# 0      Yes, I use AI tools monthly or infrequently
# 1                       Yes, I use AI tools weekly
# 2                       Yes, I use AI tools weekly
# 3                        Yes, I use AI tools daily
# 4      Yes, I use AI tools monthly or infrequently
# ...                                            ...
# 18354                   Yes, I use AI tools weekly
# 18355                    Yes, I use AI tools daily
# 18356                    Yes, I use AI tools daily
# 18357                    Yes, I use AI tools daily
# 18358                    Yes, I use AI tools daily
#
# [17413 rows x 9 columns]
